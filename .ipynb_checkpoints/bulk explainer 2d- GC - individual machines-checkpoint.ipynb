# %%
import bulk_explainer
import bulk_prepare
import prepare
import SHAP
import main
import torch
from torch.utils.data.dataloader import DataLoader
import display

# %%
data_path = 'C:/Users/User/OneDrive/Forensic science/0. Research project/samples/'
protocol_file_path =  data_path + "train.txt"
database_path = data_path + 'data/train_6.4_cqt/'  
data_type = "cqt"

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 1)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12376/1350483210.py in <module>
# ----> 1 mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 2)
#
# ~\OneDrive\Forensic science\0. Research project\code\Notebooks\dashboard\bulk_explainer.py in resnet_2d_gc(protocol_file_path, database_path, data_type, attack_type)
#     200     resnet2d_model, device = prepare.load_2d_resnet(main.weights_2d_resnet)
#     201     test_set = bulk_prepare.resnet(protocol_file_path, database_path, data_type)
# --> 202     mask_list = explain_2d_gc(test_set,  resnet2d_model, device, attack_type)
#     203     display.bulk_resnet_2d(mask_list)
#     204     return mask_list
#
# ~\OneDrive\Forensic science\0. Research project\code\Notebooks\dashboard\bulk_explainer.py in explain_2d_gc(test_set, resnet2d_model, device, attack_type)
# ...

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 3)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 4)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 5)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 6)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 7)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 8)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 9)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 10)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 11)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 102)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 103)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 104)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 105)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 106)

# %%
mask = bulk_explainer.resnet_2d_gc(protocol_file_path, database_path, data_type, 107)
