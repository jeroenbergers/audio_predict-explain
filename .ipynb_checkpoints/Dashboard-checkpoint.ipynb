# %%
import main
import soundfile as sf
import ipywidgets as widgets
from IPython.display import display
import io
import warnings
import prepare
import SHAP
import display
import IPython.display as ipd
import grad_cam
import predict

# %% [markdown]
# Upload the file (For widget upload node.js needed)

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
for name, file_info in uploader.value.items():
        sample,sr = sf.read(io.BytesIO(file_info['content']))

# %% [markdown]
# Upload file from location

# %%
#sample, sr = prepare.tanspose_audio_fragments(sample, sr)
database_path = 'C:/Users/User/OneDrive/Forensic science/0. Research project/Dataset_complete/LJ032-0081_gen.flac'
sample, sr = sf.read(database_path)

# %%
main.explain_2d_shap(database_path)
# Out:
# Resnet 2d prediction: fake with score: tensor(17.7857)
# array([[ 9.4439943e-05,  3.9056377e-04,  3.7514872e-04, ...,
#          4.4325047e-06,  6.5028180e-05,  4.9716167e-05],
#        [ 1.9151662e-04,  1.0697871e-04,  6.7684241e-04, ...,
#         -1.1682091e-05,  1.5239544e-06,  3.9833532e-05],
#        [ 5.3892151e-04, -2.8440592e-04, -2.6307654e-04, ...,
#         -1.0471880e-05,  2.8233839e-05,  3.8286998e-05],
#        ...,
#        [ 2.0616532e-03, -1.1752854e-02, -3.2601734e-03, ...,
#         -3.2045578e-03, -2.6871285e-03, -2.9212767e-03],
#        [ 4.7951969e-03, -1.6778596e-03,  5.3326371e-03, ...,
#         -1.0446594e-03, -1.4417750e-03,  6.3832704e-04],
#        [ 3.1696968e-03,  2.0025400e-03,  3.0066378e-03, ...,
#          8.4782788e-04,  1.1569293e-03,  1.2870450e-03]], dtype=float32)
