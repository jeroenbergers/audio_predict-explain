# %%
import bulk_explainer
import bulk_prepare
import prepare
import SHAP
import main
import torch
from torch.utils.data.dataloader import DataLoader
import display

# %%
data_path = 'C:/Users/User/OneDrive/Forensic science/0. Research project/samples/'
protocol_file_path =  data_path + "train.txt"
database_path = data_path + 'data/train_6/'  
data_type = "time_frame"

# %%
mask = bulk_explainer.AASIST_1d_shap(protocol_file_path, database_path, data_type, 101)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import prepare
import torch.nn.functional as F

# %%
def bulk_resnet_1d(mask_list):
    important_time = normalized((mask_list)).sum(axis=0)
    move = moving_average(important_time,300)
    move[move < 0] = 0

    heatmap = np.zeros([1,96000])
    heatmap = move
    plt.figure(figsize=(18.5, 6.5), dpi = 300)
    a = [0, 16000, 16000 * 2, 16000 * 3, 16000 * 4, 16000 * 5, 16000 * 6 ]
    labels = [0,1,2,3,4,5,6]
    limit = max(np.amax(heatmap), abs(np.amin(heatmap)))
    plt.xticks(ticks = a, labels = labels)
    plt.imshow(np.expand_dims(heatmap,axis=1).T, cmap='Reds', aspect="auto",vmin=0, vmax=limit)
    plt.colorbar()
    plt.show()

# %%
def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
bulk_resnet_1d(mask)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14636/3041924304.py in <module>
# ----> 1 mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 2)
#
# ~\OneDrive\Forensic science\0. Research project\code\Notebooks\dashboard\bulk_explainer.py in resnet_2d_shap(protocol_file_path, database_path, data_type, attack_type)
#     192     resnet2d_model, device = prepare.load_2d_resnet(main.weights_2d_resnet)
#     193     test_set = bulk_prepare.resnet(protocol_file_path, database_path, data_type)
# --> 194     mask_list = explain_2d_shap(test_set,  resnet2d_model, device, attack_type)
#     195     display.bulk_resnet_2d(mask_list)
#     196     return mask_list
#
# ~\OneDrive\Forensic science\0. Research project\code\Notebooks\dashboard\bulk_explainer.py in explain_2d_shap(test_set, resnet1d_model, device, attack_type)
# ...

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 3)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 4)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 5)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 6)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 7)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 8)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 9)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 10)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 11)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 102)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 103)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 104)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 105)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 106)

# %%
mask = bulk_explainer.resnet_2d_shap(protocol_file_path, database_path, data_type, 107)
