# %%
import sys
sys.path.append("C:/Users/jeroe/OneDrive/Forensic science/0. Research project/code/Notebooks/dashboard")
import main

# %%
data_path = 'C:/Users/jeroe/OneDrive/Forensic science/0. Research project/ToExplain/'

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)
# Out:
# AASIST prediction: fake with score: tensor(3.6349)
#   0%|          | 0/500 [00:00<?, ?it/s]
# 852.6512
# ()

# %%
example_number = 2
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 3
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 4
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 5
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 6
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 7
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 8
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 9
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
vexample_number = 10
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 12
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 13
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 14
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 15
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)

# %%
example_number = 16
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_lime(database_path)
