# %%
import sys
sys.path.append("C:/Users/jeroe/OneDrive/Forensic science/0. Research project/code/Notebooks/dashboard")
import main

# %%
data_path = 'C:/Users/jeroe/OneDrive/Forensic science/0. Research project/ToExplain/'

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -14.55713459239988
# Prediction_local [-7.55259486]
# Right: -5.2127814
# Intercept 17.593851951226924
# Prediction_local [9.54290038]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept 26.627022970464377
# Prediction_local [-9.8186039]
# Right: -15.753409
# Intercept -23.912674455863815
# Prediction_local [10.01375092]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -15.329363736843195
# Prediction_local [-6.56812782]
# Right: -5.2127814
# Intercept 18.56056814860852
# Prediction_local [8.31422625]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept 26.937797669099545
# Prediction_local [-9.36757841]
# Right: -15.753409
# Intercept -24.13505788198361
# Prediction_local [9.6261502]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.1, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -16.8349090188107
# Prediction_local [-5.31799616]
# Right: -5.2127814
# Intercept 20.260380214303723
# Prediction_local [6.92745162]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.1, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept 32.4587154359822
# Prediction_local [-15.52062583]
# Right: -15.753409
# Intercept -29.656370588077685
# Prediction_local [15.63665581]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.1, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -16.649966351199442
# Prediction_local [-5.26969066]
# Right: -5.2127814
# Intercept 20.032347805557766
# Prediction_local [6.86719769]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.1, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept 33.11769936277143
# Prediction_local [-15.5093784]
# Right: -15.753409
# Intercept -30.180873664243798
# Prediction_local [15.6279425]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.01, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -5.2127814292907715
# Prediction_local [-5.21278143]
# Right: -5.2127814
# Intercept 6.803704738616943
# Prediction_local [6.80370474]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.01, random_state=41, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -15.753409385681152
# Prediction_local [-15.75340939]
# Right: -15.753409
# Intercept 15.864530563354492
# Prediction_local [15.86453056]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.01, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -5.2127814292907715
# Prediction_local [-5.21278143]
# Right: -5.2127814
# Intercept 6.803704738616943
# Prediction_local [6.80370474]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.01, random_state=42, sample_n=3000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Intercept -15.753409385681152
# Prediction_local [-15.75340939]
# Right: -15.753409
# Intercept 15.864530563354492
# Prediction_local [15.86453056]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=1000)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Intercept -16.66357325401505
# Prediction_local [-5.24579863]
# Right: -5.2127814
# Intercept 20.05045201818375
# Prediction_local [6.84209861]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=1000)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Intercept 32.49658720336788
# Prediction_local [-15.65935495]
# Right: -15.753409
# Intercept -29.69892252685188
# Prediction_local [15.7737615]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=500)
# Out:
# Resnet 1d prediction: fake with score: tensor(6.8037)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/500 [00:00<?, ?it/s]
# Intercept -16.84394928840158
# Prediction_local [-5.23393675]
# Right: -5.2127814
# Intercept 20.272352754775774
# Prediction_local [6.82787763]
# Right: 6.8037047
# 0.009246826171875
# 1357.6851806640625
# 790.4967041015625
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_1d_lime(database_path, kernel_size=0.5, random_state=41, sample_n=500)
# Out:
# Resnet 1d prediction: bonafide with score: tensor(-15.7534)
# kernel 0.6, rs 41, samples 1000
#   0%|          | 0/500 [00:00<?, ?it/s]
# Intercept 32.628918297078066
# Prediction_local [-15.68673791]
# Right: -15.753409
# Intercept -29.819048404406402
# Prediction_local [15.80110709]
# Right: 15.864531
# -0.02191162109375
# 1307.5772094726562
# 808.7279968261719
# array([0., 0., 0., ..., 0., 0., 0.])
