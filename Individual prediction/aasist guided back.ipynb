# %%
import sys
sys.path.append("C:/Users/user/OneDrive/Forensic science/0. Research project/code/Notebooks/dashboard")
import main

# %%
data_path = 'C:/Users/user/OneDrive/Forensic science/0. Research project/ToExplain/'

# %%
example_number = 1 
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(3.0356)
# tensor([[-4.6184e-04, -1.1363e-03,  4.8264e-04,  ..., -7.2562e-06,
#          -6.3526e-06,  0.0000e+00]])
# torch.Size([1, 43608])
# 1176.0566

# %%
example_number = 2
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(3.6500)
# tensor([[-2.1871e-04, -2.3786e-04, -4.0367e-05,  ..., -6.3881e-07,
#           0.0000e+00,  0.0000e+00]])
# torch.Size([1, 55126])
# 1184.6932

# %%
example_number = 3
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-3.0012)
# tensor([[ 1.8296e-04,  2.9803e-04,  7.2105e-04,  ..., -9.5757e-06,
#           0.0000e+00,  0.0000e+00]])
# torch.Size([1, 31126])
# 860.1923

# %%
example_number = 4
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(3.4196)
# tensor([[-5.0932e-05, -1.5018e-05, -3.8229e-05,  ...,  5.4706e-07,
#           1.2275e-06,  0.0000e+00]])
# torch.Size([1, 64779])
# 356.94992

# %%
example_number = 5
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(4.9568)
# tensor([[ 3.0193e-04,  5.3885e-05, -2.9749e-04,  ..., -6.0383e-06,
#          -7.3308e-06, -9.8155e-06]])
# torch.Size([1, 33833])
# 341.79108

# %%
example_number = 6
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(3.3572)
# tensor([[-7.5567e-05, -3.6790e-04, -1.2141e-03,  ..., -1.0622e-06,
#           1.8180e-06, -2.8374e-06]])
# torch.Size([1, 124274])
# 1751.9698

# %%
example_number = 7
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: fake with score: tensor(2.7794)
# tensor([[-2.5500e-04, -4.7384e-04, -3.1150e-04,  ...,  2.9418e-06,
#           2.0655e-06,  5.3684e-06]])
# torch.Size([1, 142478])
# 2341.536

# %%
example_number = 8
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(0.2141)
# tensor([[-2.0706e-04,  8.7874e-04,  5.2473e-05,  ..., -2.2311e-06,
#          -8.1524e-08,  2.6709e-11]])
# torch.Size([1, 135605])
# 2970.9407

# %%
example_number = 9
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-5.7382)
# tensor([[-1.4143e-03,  8.0602e-03,  9.7754e-03,  ..., -2.7553e-05,
#           0.0000e+00,  0.0000e+00]])
# torch.Size([1, 18133])
# 1352.4915

# %%
example_number = 10
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-1.3544)
# tensor([[-1.6474e-04, -3.0517e-04, -2.0179e-04,  ..., -4.8320e-06,
#           1.2904e-05,  0.0000e+00]])
# torch.Size([1, 122775])
# 1482.6165

# %%
example_number = 11
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-7.1545)
# tensor([[-5.4206e-04, -1.2373e-03,  6.9471e-04,  ...,  2.0448e-06,
#          -2.1241e-06,  0.0000e+00]])
# torch.Size([1, 51027])
# 1314.8987

# %%
example_number = 12
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-6.3563)
# tensor([[-7.4503e-04, -8.3376e-04,  1.5742e-03,  ...,  3.1568e-05,
#           2.5290e-05,  0.0000e+00]])
# torch.Size([1, 46080])
# 1477.0365

# %%
example_number = 13
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-8.6294)
# tensor([[ 1.0029e-03,  1.4580e-03,  1.1484e-04,  ..., -3.4877e-06,
#           0.0000e+00,  0.0000e+00]])
# torch.Size([1, 36895])
# 1209.512

# %%
example_number = 14
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-5.7382)
# tensor([[-1.4143e-03,  8.0602e-03,  9.7754e-03,  ..., -2.7553e-05,
#           0.0000e+00,  0.0000e+00]])
# torch.Size([1, 18133])
# 1352.4915

# %%
example_number = 15
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-7.7793)
# tensor([[3.9488e-04, 3.7143e-04, 5.8237e-04,  ..., 2.4653e-07, 0.0000e+00,
#          0.0000e+00]])
# torch.Size([1, 150208])
# 1992.7489

# %%
example_number = 16
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-3.9780)
# tensor([[ 6.2618e-04,  1.3402e-03,  4.4614e-04,  ..., -6.3176e-06,
#          -1.3026e-05,  0.0000e+00]])
# torch.Size([1, 42987])
# 1384.5879

# %%
example_number = 17
database_path = data_path + str(example_number) + "/explain.flac"
main.explain_aasist_guided(database_path)
# Out:
# AASIST prediction: bonafide with score: tensor(-5.0025)
# tensor([[-0.0004, -0.0006,  0.0002,  ...,  0.0000,  0.0000,  0.0000]])
# torch.Size([1, 66560])
# 921.0071
