# %%
sys.path.append("C:/Users/user/OneDrive/Forensic science/0. Research project/code/Notebooks/dashboard")

import bulk_explainer
import bulk_prepare
import prepare
import SHAP
import main
import torch
from torch.utils.data.dataloader import DataLoader
import display

# %%
data_path = 'D:/audio files/dataset_complete_split/'
protocol_file_path =  data_path + "train.txt"
database_path = data_path + 'data/train_6/'  
data_type = "time_frame"

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 1)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 2)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 3)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 4)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 5)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 6)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 7)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 8)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 9)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 10)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 11)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 102)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 103)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 104)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 105)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 106)

# %%
mask = bulk_explainer.resnet_1d_gc(protocol_file_path, database_path, data_type, 107)
